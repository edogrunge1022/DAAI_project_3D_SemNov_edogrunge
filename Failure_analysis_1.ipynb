# %%
# %cd '/content'
# Out:
# /content

# %%
# !git clone https://github.com/antoalli/SemNov_AML_DAAI_23-24
# Out:
# Cloning into 'SemNov_AML_DAAI_23-24'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 160 (delta 57), reused 149 (delta 48), pack-reused 0
# Receiving objects: 100% (160/160), 135.09 KiB | 11.26 MiB/s, done.
# Resolving deltas: 100% (57/57), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp -av  '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates/ood_utils.py' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/utils'
# !cp -av  '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates/trainer_cla_md.py' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/classifiers'
# Out:
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates/ood_utils.py' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/utils/ood_utils.py'
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates/trainer_cla_md.py' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/classifiers/trainer_cla_md.py'

# %%
# %cd /content/SemNov_AML_DAAI_23-24
# Out:
# /content/SemNov_AML_DAAI_23-24

# %%
# %cd /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24
# Out:
# /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24

# %%
# to download the dataset
# !sh download_data.sh
# Out:
# ...
# ============Downloading ModelNet40 + OOD Splits in
# --2024-01-23 13:49:49--  https://www.dropbox.com/s/c2x3h59nxprjs21/modelnet40_normal_resampled.tar?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.2.18, 2620:100:6017:18::a27d:212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.2.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar [following]
# --2024-01-23 13:49:50--  https://www.dropbox.com/s/dl/c2x3h59nxprjs21/modelnet40_normal_resampled.tar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc63c7960324ec75e4294732c37e.dl-eu.dropboxusercontent.com/cd/0/get/CL5s6PgXd8vjU0RL0OxDAs7FRb3yWzA3rfyhQrL07daGwISC_DSlxz5Uv2kPbq6NlwJf3EUpRUQex1SdgPUX3TR-wGzgzJ7NutfPxhVdd1_5yM_OC1eJH100s0tuuy14-R2qbWv-UvJdNpU4aL4T4p7n/file?dl=1# [following]
# ...

# %%
# installing minimal requirements
# !pip install timm==0.5.4 wandb tqdm h5py==3.6.0 protobuf==3.20.1 lmdb==1.2.1 msgpack-numpy==0.4.7.1 scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.5/881.5 kB 46.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.8/257.8 kB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# ...
#   Created wheel for lmdb: filename=lmdb-1.2.1-cp310-cp310-linux_x86_64.whl size=265649 sha256=a7d61d191dfdf9d17e78a73a3aa0c4f2808fc0044f84baffe679c333e6146c57
#   Stored in directory: /root/.cache/pip/wheels/ae/36/fc/13e586283759d30c3efc3d0b917b2c5f1b69d171de8b7ed204
# ...

# %%
# !pip install "https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl"
# !pip install ninja==1.10.2.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 3.0 MB/s eta 0:00:00
# ...

# %%
# if output is not present in the repository
# !cp -av '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/2812_outputs1/outputs' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24'
# Out:
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/2812_outputs1/outputs' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/outputs'
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/2812_outputs1/outputs/DGCNN_CE_SR1' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1'
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/2812_outputs1/outputs/DGCNN_CE_SR1/backup-code' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1/backup-code'
# '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/2812_outputs1/outputs/DGCNN_CE_SR1/backup-code/datasets' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/outputs/DGCNN_CE_SR1/backup-code/datasets'
# ...

# %%
# %cd /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24
# Out:
# /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24

# %%
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE \
    -mode eval --ckpt_path outputs/DGCNN_CE_SR1/models/model_last.pth
# Out:
# Cannot import torchlars
# Cannot load RSCNN: No module named 'pointnet2_ops'
# Cannot load PCT: No module named 'pointnet2_ops'
# Cannot load PointMLP: No module named 'pointnet2_ops'
# Cannot load PointNet2: No module named 'pointnet2_ops'
# out-of-distribution eval - Modelnet -> SONN ..
# ...

# %%
# !cp -av '/content/SemNov_AML_DAAI_23-24/utils/ood_utils.py' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates'
#!cp -av '/content/SemNov_AML_DAAI_23-24/classifiers/trainer_cla_md.py' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates'
# Out:
# '/content/SemNov_AML_DAAI_23-24/utils/ood_utils.py' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/Repo_updates/ood_utils.py'

# %%
# !cp -av '/content/SemNov_AML_DAAI_23-24/img2' '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/failure_analysis/dgcnn_sr1/img_tar1'
# Out:
# '/content/SemNov_AML_DAAI_23-24/img2' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/failure_analysis/dgcnn_sr1/img_tar1/img2'
# '/content/SemNov_AML_DAAI_23-24/img2/prediction_chair_label_toilet_602.jpg' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/failure_analysis/dgcnn_sr1/img_tar1/img2/prediction_chair_label_toilet_602.jpg'
# '/content/SemNov_AML_DAAI_23-24/img2/prediction_chair_label_toilet_566.jpg' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/failure_analysis/dgcnn_sr1/img_tar1/img2/prediction_chair_label_toilet_566.jpg'
# '/content/SemNov_AML_DAAI_23-24/img2/prediction_chair_label_toilet_603.jpg' -> '/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/outputs/failure_analysis/dgcnn_sr1/img_tar1/img2/prediction_chair_label_toilet_603.jpg'
# ...

# %% [markdown]
# # **Data visualization**

# %%
# !pip install open3d
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.7/399.7 MB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 69.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 96.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.6
#     Uninstalling widgetsnbextension-3.6.6:
#       Successfully uninstalled widgetsnbextension-3.6.6
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# ...

# %%
#data read and write
import numpy as np
import h5py
#visualization
import open3d as o3d
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import plotly.graph_objects as go

# %%
pc_h5 = h5py.File('/content/gdrive/MyDrive/AI project - 3D semantic novelty detection/SemNov_AML_DAAI_23-24/3D_OS_release_data/ScanObjectNN/h5_files/main_split/test_objectdataset_augmented25rot.h5', 'r')
point_clouds = np.array(pc_h5['data'])
labels = np.array(pc_h5['label'])

# %%
print('Size of Point Clouds:', point_clouds.shape)
print('labels:', labels)
# Out:
# Size of Point Clouds: (2893, 2048, 3)
# labels: [ 0  0  0 ... 14 14 14]

# %%
# label: 13 - sofa
figure = go.Figure(
    data=[
        go.Scatter3d(
            x=point_clouds[281,:,0], y=point_clouds[281,:,1], z=point_clouds[281,:,2],
            mode='markers',
            marker=dict(size=1)
        )
    ]
)
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
